# %% [markdown]
# <a href="https://colab.research.google.com/github/muralivantaku/muralivantaku2/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('ss dvs.csv')
df.head(15)
# Out:
#     Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0            1       1  female  0.19    0.55        1        4       1
# 1            2       1  female  0.19    0.45        1        2       1
# 2            3       1    male  0.19    0.90        3        0       0
# 3            4       1    male  0.19    0.15        1        0       0
# 4            5       1    male  0.19    0.45        2        5       1
# 5            6       1  female  0.19    0.35        5        1       9
# 6            7       1  female  0.19    0.55        4        0       2
# 7            8       1  female  0.19    0.15        3        0       6
# 8            9       1  female  0.19    0.65        2        0       5
# 9           10       1    male  0.19    0.15        1        0       0
# 10          11       1    male  0.19    0.45        1        0       0
# 11          12       1    male  0.19    0.25        2        0       2
# ...

# %%
df.tail(10)
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 5180        5181       0    male  0.19    0.25        1        0       1
# 5181        5182       0    male  0.19    0.75        1        0       0
# 5182        5183       0  female  0.19    0.45        0        0       0
# 5183        5184       0    male  0.22    1.10        0        0       0
# 5184        5185       0    male  0.22    1.50        0        0       0
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# 5180      no      yes        no       no       no
# 5181      no       no        no       no       no
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %%
df.shape
# Out:
# (5190, 13)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
df['illness'].value_counts()
# Out:
# 1    1638
# 0    1554
# 2     946
# 3     542
# 4     274
# 5     236
# Name: illness, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# female    2702
# male      2488
# Name: gender, dtype: int64

# %%
y=list(df.income)
plt.boxplot(y)
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
df.groupby(['gender','reduced']).mean()
# Out:
# <ipython-input-17-7beb99933e54>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['gender','reduced']).mean()
#                  Unnamed: 0    visits       age    income   illness    health
# gender reduced
# female 0        2524.038512  0.229322  0.465755  0.482735  1.462144  1.115098
#        1        1985.768421  0.400000  0.325684  0.542105  2.242105  1.610526
#        2        1622.618182  0.672727  0.391455  0.560182  2.236364  1.781818
#        3         997.311111  1.333333  0.403111  0.516000  2.733333  1.733333
#        4        1237.740741  0.851852  0.458889  0.466667  2.222222  2.074074
#        5        1169.055556  1.444444  0.401667  0.614444  2.222222  2.500000
#        6        1382.545455  1.363636  0.426364  0.622727  2.363636  1.363636
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <ipython-input-18-5e2cb1188e72>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# <Axes: >

# %%
# relation between income and visits
plt.figure(figsize=(10,10))
plt.scatter(x='income',y='visits',data=df)
plt.xlabel('income')
plt.ylabel('visits')
# Out:
# Text(0, 0.5, 'visits')

# %%
sns.histplot(df.gender,bins=2)
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %%
db=df.groupby('gender')['reduced'].sum().to_frame().reset_index()
#creating the bar chart
plt.barh(db['gender'],db['reduced'],color=['cornflowerblue','lightseagreen'])
#adding the aesthetics
plt.title('Bar Chart')
plt.xlabel('gender')
plt.ylabel('reduced activity')
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
df.groupby(['age']).mean()
# Out:
# <ipython-input-23-c9e90997d916>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['age']).mean()
#        Unnamed: 0    visits    income   illness   reduced    health
# age
# 0.19  2387.335106  0.212766  0.418338  1.247340  0.519947  1.186170
# 0.22  2617.739489  0.201154  0.650932  1.197032  0.612531  1.098104
# 0.27  2748.388145  0.258126  0.847055  1.137667  0.745698  1.191205
# 0.32  2825.132890  0.242525  0.933123  1.222591  0.694352  1.488372
# 0.37  2804.308219  0.246575  0.887466  1.287671  1.239726  1.404110
# 0.42  2940.873016  0.317460  0.841984  1.206349  1.111111  1.158730
# 0.47  2857.834254  0.270718  0.748011  1.314917  0.552486  1.132597
# 0.52  2547.540541  0.414414  0.669775  1.608108  1.220721  1.346847
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
df['freepoor'].hist()
plt.xlabel('freepoor')
plt.ylabel('count')
plt.title('freepoor count')
plt.show()

# %%
df['age'].hist()
plt.xlabel('age')
plt.ylabel('count')
plt.title('age count')
plt.show()

# %%
df['gender'].hist()
plt.xlabel('gender')
plt.ylabel('count')
plt.title('gender count')
plt.show()

# %%
df.duplicated().any()
# Out:
# False

# %%
df=df.drop_duplicates()
df
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0              1       1  female  0.19    0.55        1        4       1
# 1              2       1  female  0.19    0.45        1        2       1
# 2              3       1    male  0.19    0.90        3        0       0
# 3              4       1    male  0.19    0.15        1        0       0
# 4              5       1    male  0.19    0.45        2        5       1
# ...          ...     ...     ...   ...     ...      ...      ...     ...
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
top_10=df.nlargest(10,'visits').set_index('age')

# %%
sns.barplot(x='visits',y=top_10.index,data=top_10)
# Out:
# <Axes: xlabel='visits', ylabel='age'>
